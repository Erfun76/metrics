# %%
# !cp -RT 'drive/MyDrive/metrics' 'metrics'

# %%
# %cd metrics
# Out:
# /content/metrics

# %%
# !pip install mmcv
# Out:
# ...
#      |████████████████████████████████| 225kB 4.2MB/s
# ...
#      |████████████████████████████████| 194kB 19.7MB/s
# ...
#   Created wheel for mmcv: filename=mmcv-1.2.5-py2.py3-none-any.whl size=325724 sha256=5ae0377088f5a1b1b4bf0b043946f65be3cc58e87a08f4e88f4421243d111474
#   Stored in directory: /root/.cache/pip/wheels/96/32/e0/3ffb0cfb0520b0876b186c15e0df5de9ac46891465eabb7e76
# Successfully built mmcv
# ...

# %%
# !python quality_calc.py
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# 2
# [[14.80301034]]
# niqe: 7.402

# %%
# !python quality_calc.py -q FR
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Setting up Perceptual loss...
# Loading model from: /content/metrics/PerceptualSimilarity/models/weights/v0.1/alex.pth
# ...[net-lin [alex]] initialized
# ...Done
# ['valid_lr.png'] ['.ipynb_checkpoints', 'valid_gen.png']
# /content/metrics/Ssim/ssim.py:4: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
#   return compare_ssim(p0, p1, data_range=range, multichannel=True)
# Distance: 0.391
# Ssim: 0.859

# %%
# !cp -RT 'metrics' 'drive/MyDrive/metrics'
